# %%
import matplotlib.pyplot as plt
from tkinter import *
import nltk
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
nltk.download('popular')
nltk.download('nps_chat')
nltk.download('webtext')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# True

# %%
text7
# Out:
# <Text: Wall Street Journal>

# %%
text = " ".join(text7)
text_corrected = " ".join(word for word in text7 if word.isalpha())
word_list = nltk.word_tokenize(text_corrected)

# %%
freq_dist = FreqDist(word_list)
hapaxes = freq_dist.hapaxes()
low_freq_words = [word for word, freq in freq_dist.items() if freq < 5]
print("Слова-унікаліними (hapaxes):", hapaxes)
print("Слова, які зустрічаються менше 5 разів:", low_freq_words)
# Out:
# Слова-унікаліними (hapaxes): ['Pierre', 'Elsevier', 'Agnew', 'fiber', 'resilient', 'lungs', 'symptoms', 'Loews', 'Micronite', 'spokewoman', 'properties', 'filter', 'Four', 'diagnosed', 'malignant', 'mesothelioma', 'asbestosis', 'morbidity', 'Groton', 'stringently', 'smooth', 'classified', 'amphobiles', 'Brooke', 'pathlogy', 'Vermont', 'curly', 'Environmental', 'Protection', 'gradual', 'outlawed', 'Areas', 'dusty', 'burlap', 'sacks', 'bin', 'poured', 'cotton', 'acetate', 'mechanically', 'clouds', 'dust', 'hung', 'ventilated', 'Darrell', 'Yields', 'tracked', 'IBC', 'fraction', 'Compound', 'reinvestment', 'lengthened', 'longest', 'Donoghue', 'Longer', 'Shorter', 'Brenda', 'Malizia', 'Negus', 'rises', 'pour', 'Assets', 'Dreyfus', 'invests', 'waiving', 'Bolduc', 'Terrence', 'Daniels', 'Royal', 'Trustco', 'McDermott', 'Babcock', 'Wilcox', 'Wickliffe', 'computerized', 'Legislation', 'ensnarled', 'earliest', 'Clark', 'oversee', 'biannual', 'powwow', 'titans', 'sunny', 'confines', 'Hoosier', 'royalty', 'rock', 'buckle', 'Rust', 'rusty', 'Maytag', 'lesser', 'knowns', 'Trojan', 'Queen', 'Cheese', 'starters', 'Hudnut', 'Symphony', 'Orchestra', 'guest', 'Borge', 'dessert', 'escort', 'busloads', 'wives', 'raced', 'Speedway', 'unimpeded', 'traffic', 'lieutenant', 'breakfast', 'drinks', 'everyday', 'speedway', 'hauled', 'crews', 'Fortune', 'drooled', 'schoolboys', 'dummies', 'Back', 'execs', 'boarding', 'dancing', 'moons', 'renovated', 'Roof', 'ballroom', 'hottest', 'duckling', 'mousseline', 'lobster', 'consomme', 'veal', 'mignon', 'chocolate', 'terrine', 'raspberry', 'sauce', 'Knowing', 'tasty', 'eat', 'ovation', 'tempts', 'heartland', 'winter', 'sluggishness', 'Preliminary', 'tallies', 'cloud', 'Exports', 'gloomy', 'accumulated', 'Post', 'discounts', 'fixtures', 'underscore', 'Mortimer', 'Zuckerman', 'guaranteed', 'subscriber', 'Circulation', 'awards', 'renewal', 'shore', 'Publishers', 'giveaways', 'subscribers', 'telephones', 'Audit', 'Circulations', 'newsweekly', 'payoff', 'Westborough', 'Manchester', 'efficiencies', 'evaluated', 'emerges', 'attracts', 'Wilbur', 'Rothschild', 'cluttered', 'Regulatory', 'refile', 'expedited', 'FERC', 'Ricken', 'Toys', 'R', 'Us', 'Deane', 'Signet', 'Rexinger', 'Glauber', 'ratepayers', 'overruns', 'entertain', 'pool', 'hostage', 'slash', 'tracking', 'addresses', 'nightmare', 'disputed', 'collecting', 'refunded', 'calculations', 'differential', 'Appellate', 'LaSalle', 'Automobile', 'setting', 'arising', 'consumption', 'Chinchon', 'diversifying', 'fledgling', 'depend', 'longevity', 'Documents', 'scrapped', 'operational', 'prototype', 'needing', 'promissory', 'complicate', 'tricky', 'unproven', 'gallium', 'arsenide', 'robotic', 'twice', 'Hitachi', 'existed', 'Regarded', 'Davenport', 'Blanchard', 'Hammerton', 'Wheeland', 'Pardus', 'Carney', 'Tassinari', 'diplomacy', 'watching', 'copyrights', 'India', 'investigations', 'genuine', 'touchy', 'denial', 'harms', 'inventiveness', 'offending', 'citizens', 'protections', 'discouraging', 'deterring', 'lauded', 'pirates', 'initialing', 'amending', 'trademark', 'unauthorized', 'showings', 'compel', 'parlors', 'enact', 'compatible', 'literary', 'Greece', 'Hoffman', 'specializing', 'retaliation', 'improvements', 'craft', 'developments', 'piracy', 'disregard', 'halve', 'declaration', 'Economy', 'Nestor', 'Latin', 'aspires', 'external', 'Miguel', 'Alurralde', 'Assistant', 'Mulford', 'negotiator', 'Carballo', 'Menem', 'centennial', 'milestones', 'THREE', 'COMPUTERS', 'THAT', 'CHANGED', 'Commodore', 'Pet', 'Tandy', 'audiocassettes', 'garage', 'Wozniak', 'Jobs', 'hobbyists', 'Homebrew', 'Club', 'affordable', 'explosive', 'desktop', 'mainframe', 'Altair', 'Sol', 'IMSAI', 'keyboards', 'contributors', 'billionaire', 'adapted', 'Shugart', 'Seagate', 'Hayes', 'Dale', 'Heatherington', 'modems', 'Purepac', 'label', 'Strait', 'Broken', 'Output', 'gradually', 'reaches', 'Perch', 'Dolphin', 'Seahorse', 'Tarwhine', 'Sloan', 'Following', 'gelatin', 'capsules', 'divest', 'possessions', 'Gener ...
# Слова, які зустрічаються менше 5 разів: ['Pierre', 'Vinken', 'join', 'Elsevier', 'Dutch', 'Rudolph', 'Agnew', 'Consolidated', 'Gold', 'Fields', 'conglomerate', 'cigarette', 'exposed', 'fiber', 'unusually', 'resilient', 'enters', 'lungs', 'exposures', 'symptoms', 'decades', 'Loews', 'Micronite', 'appear', 'forum', 'spokewoman', 'talking', 'heard', 'questionable', 'properties', 'aware', 'smokers', 'useful', 'users', 'Talcott', 'Cancer', 'Harvard', 'modest', 'filter', 'died', 'Four', 'surviving', 'diagnosed', 'malignant', 'mesothelioma', 'lung', 'asbestosis', 'morbidity', 'striking', 'Groton', 'industrialized', 'Hollingsworth', 'Vose', 'regulate', 'stringently', 'chrysotile', 'buildings', 'regulation', 'smooth', 'fibers', 'classified', 'amphobiles', 'Brooke', 'Mossman', 'pathlogy', 'Vermont', 'curly', 'body', 'explained', 'Environmental', 'Protection', 'imposed', 'gradual', 'outlawed', 'Areas', 'dusty', 'Workers', 'dumped', 'burlap', 'sacks', 'imported', 'bin', 'poured', 'cotton', 'acetate', 'mechanically', 'dry', 'clouds', 'dust', 'hung', 'exhaust', 'fans', 'ventilated', 'contracted', 'Darrell', 'Phillips', 'human', 'recognize', 'events', 'bearing', 'Yields', 'amid', 'compound', 'taxable', 'tracked', 'IBC', 'eased', 'fraction', 'Compound', 'assume', 'reinvestment', 'maturity', 'lengthened', 'longest', 'Donoghue', 'Longer', 'maturities', 'indicate', 'declining', 'permit', 'retain', 'Shorter', 'capture', 'sooner', 'indicator', 'Nevertheless', 'Brenda', 'Malizia', 'Negus', 'blip', 'rises', 'pour', 'Assets', 'grew', 'Typically', 'comparable', 'vary', 'Dreyfus', 'Dollar', 'invests', 'waiving', 'boosts', 'simple', 'slid', 'Bolduc', 'Grace', 'holds', 'succeeds', 'Terrence', 'Daniels', 'formerly', 'Royal', 'Trustco', 'obtain', 'McDermott', 'Babcock', 'Wilcox', 'Bailey', 'Controls', 'Operations', 'Finmeccanica', 'Italian', 'mechanical', 'Wickliffe', 'computerized', 'controls', 'employs', 'lifted', 'acts', 'obligations', 'borrowing', 'midnight', 'Legislation', 'lift', 'ensnarled', 'fight', 'taxes', 'earliest', 'Clark', 'Vitulli', 'arm', 'Mazda', 'oversee', 'Previously', 'biannual', 'powwow', 'titans', 'typically', 'jet', 'sunny', 'confines', 'resort', 'towns', 'Boca', 'Raton', 'Hot', 'Springs', 'Manufacturers', 'Hoosier', 'Indianapolis', 'treat', 'guests', 'royalty', 'rock', 'stars', 'owners', 'buckle', 'Rust', 'Belt', 'rusty', 'receiving', 'message', 'giants', 'Du', 'Pont', 'Maytag', 'lesser', 'knowns', 'Trojan', 'Queen', 'Cheese', 'Factory', 'starters', 'joined', 'Mayor', 'Hudnut', 'III', 'evening', 'Symphony', 'Orchestra', 'guest', 'Victor', 'Borge', 'Champagne', 'dessert', 'morning', 'escort', 'busloads', 'wives', 'raced', 'Speedway', 'unimpeded', 'traffic', 'red', 'lights', 'governor', 'lieutenant', 'welcomed', 'buffet', 'breakfast', 'museum', 'drinks', 'banned', 'everyday', 'visitors', 'speedway', 'hauled', 'drivers', 'crews', 'exhibition', 'race', 'Fortune', 'drooled', 'schoolboys', 'dummies', 'pointed', 'machines', 'sponsor', 'Back', 'downtown', 'execs', 'squeezed', 'hotel', 'boarding', 'buses', 'dinner', 'dancing', 'moons', 'renovated', 'Roof', 'ballroom', 'hottest', 'chefs', 'town', 'fed', 'duckling', 'mousseline', 'lobster', 'consomme', 'veal', 'mignon', 'chocolate', 'terrine', 'raspberry', 'sauce', 'Knowing', 'tasty', 'meal', 'eat', 'ovation', 'CEOs', 'tempts', 'heartland', 'forward', 'winter', 'February', 'reflecting', 'sluggishness', 'released', 'Preliminary', 'tallies', 'Industry', 'setback', 'casting', 'cloud', 'Exports', 'mere', 'boom', 'prolonged', 'disputes', 'conflicts', 'Government', 'gloomy', 'recorded', 'surplus', 'accumulated', 'Imports', 'incentive', 'Post', 'Plans', 'discounts', 'maintaining', 'permanent', 'fixtures', 'weeklies', 'underscore', 'fierce', 'Warner', 'Mortimer', 'Zuckerman', 'Alan', 'Spoon', 'lowered', 'guaranteed', 'effectively', 'subscriber', 'announce', 'Circulation', 'Credit', 'Plan', 'awards', 'credits', 'renewal', 'reward', 'bonuses', 'exceed', 'shore', 'Publishers', 'Information', 'Bureau', 'm ...

# %%
word_lengths = [len(word) for word in word_list]

length_freq_dist = FreqDist(word_lengths)

sorted_keys = sorted(length_freq_dist.keys())
sorted_values = [length_freq_dist[key] for key in sorted_keys]

plt.plot(sorted_keys, sorted_values)
plt.xticks(range(min(sorted_keys), max(sorted_keys)+1))
plt.xlabel('Довжина слова')
plt.ylabel('Частота')
plt.title('Графік довжини слів до їх частоти (відсортований)')

plt.show()

# %%
sent_list = nltk.sent_tokenize(text)
auxilliary_matrix = [[word for word in nltk.word_tokenize(sentence) if word.isalpha() and word != 'T'and word != 'U'] for sentence in sent_list]
last_words = [auxilliary_matrix[i][-1] for i in range(len(auxilliary_matrix)) if auxilliary_matrix[i] != []]
freq_dist_last_words = FreqDist(last_words)
freq_dist_last_words.most_common(10)
# Out:
# [('said', 106),
#  ('million', 51),
#  ('to', 50),
#  ('says', 39),
#  ('year', 38),
#  ('in', 35),
#  ('share', 34),
#  ('trading', 30),
#  ('it', 28),
#  ('billion', 24)]

# %%
f=open('Shining.txt', 'r', encoding='UTF-8')
raw = f.read( )
tokens = nltk.word_tokenize(raw)
text_king = nltk.Text(tokens)

# %%
text_king.concordance('monstrous')
# Out:
# Displaying 5 of 5 matches:
# d the wheel of an old jalopy , the monstrous assault on his son , the incident
#  his belly , head throbbing like a monstrous bladder . The moving wasp , having
# ed open cockpit , it looked like a monstrous mechanized wasp . When it was runn
# after he struggled up and over the monstrous snow-dune that had drifted in on t
# ibbering in at her , the face of a monstrous lunatic that had been hiding in th

# %%
print("\nWords similar to 'darkness':")
text_king.similar('darkness')
# Out:
# Words similar to 'darkness':
# door overlook hotel road stairs floor room way window time one
# snowmobile other corner wall day tub bed night snow

# %%
words_king = ['light', 'bad', 'darkness']
text_king.dispersion_plot(words_king)

# %%
freq_dist_king = nltk.FreqDist(text_king)
hapaxes_king = freq_dist_king.hapaxes()
hapaxes_king
# Out:
# ['Annotation',
#  'atmospheric',
#  'reconnecting',
#  'idyllic',
#  'feels',
#  '...',
#  'forces',
#  'uniquely',
#  'Matters1',
#  'Day8',
#  'Nest14',
#  'Snowbound26',
#  'Death38',
#  'editor',
#  'Thompson',
#  'contribution',
#  'K.',
#  'stood…',
#  'ebony',
#  'pendulum',
#  'monotonous',
#  'clang',
#  'stricken',
#  'exceedingly',
#  'emphasis',
#  'musicians',
#  'constrained',
#  'pause…',
#  'hearken',
#  'thus',
#  'waltzers',
#  'perforce',
#  'evolutions',
#  'giddiest',
#  'sedate',
#  'pervaded',
#  'assembly…',
#  '[',
#  ']',
#  'nervousness…',
#  'vows',
#  'produce',
#  'minutes…',
#  'tremulousness',
#  'revel…',
#  'POE',
#  'Masque',
#  'GOYA',
#  'FOLK',
#  'SAYING',
#  'five-five',
#  'prissy',
#  'domain',
#  'carnation',
#  'undertaker',
#  'desk-under',
#  'lapses',
#  'Rolodex',
#  'course.',
#  'intimidated',
#  'woman.',
#  'self-reliant',
#  'five-year-old.',
#  'Tensor',
#  'plans.',
#  'walnut',
#  'cologne',
#  'Leather',
#  'clamp',
#  'bray',
#  'gearing',
#  'bric-a-brac',
#  'successive',
#  'bait',
#  'sowed',
#  'one-in-a-hundred',
#  'inhabits',
#  'Hotel.',
#  'circumstances.',
#  'Humiliating',
#  'goof',
#  'rattrap',
#  'scholarly',
#  'suites',
#  'views.',
#  'salestalk',
#  'doubles',
#  'singles',
#  'Plus',
#  'storeroom',
#  'banquet',
#  'facility',
#  'speak.',
#  'impressively',
#  'minute…',
#  'Desk',
#  'lonesome',
#  'magician',
#  'heavyweight',
#  'interviewer',
#  'interviewee',
#  'supplicant',
#  'patron',
#  'pin',
#  'STAFF',
#  'sits',
#  'officious-',
#  'fifteenth',
#  'thirtieth',
#  'employs',
#  'judgment',
#  'deserves.',
#  'insultingly',
#  '1907',
#  '1909',
#  'Townley',
#  'Vanderbilts',
#  'Rockefellers',
#  'Astors',
#  'Du',
#  'Pouts',
#  'Nixon.',
#  'proud',
#  'proved',
#  '1915',
#  '1929',
#  '1936',
#  'renovated',
#  'film',
#  'producer',
#  'entrepreneur.',
#  'gold…',
#  'funneled',
#  'decrepit',
#  'relic',
#  'showplace',
#  'admiring',
#  'arrived.',
#  'British',
#  'forebear',
#  'Croquet',
#  'bastardized',
#  'According',
#  'secretary',
#  'Ours',
#  'America.',
#  'life-sized',
#  'Wiggly',
#  'equally',
#  'associates',
#  'owners',
#  'accounts',
#  'decades.',
#  'fussy',
#  'justified',
#  'admittedly',
#  'depreciation',
#  'shortens',
#  'winters',
#  'rotating',
#  'repair',
#  'repairs',
#  'elements',
#  'foothold',
#  'contingency',
#  'tragedy.',
#  'appraisingly',
#  'grin-the',
#  'antithesis',
#  'grin-',
#  'retired.',
#  'job…',
#  '1970-71',
#  'refurbished',
#  'this…',
#  'harshness',
#  'Gradys',
#  'months.',
#  'chopper',
#  'two.',
#  'frequencies',
#  'apt',
#  'also.',
#  'Suppose',
#  'half…',
#  'Parks',
#  'Rescue',
#  'hours…',
#  'optimum',
#  'injured',
#  'below-or',
#  'factor',
#  'reasoned',
#  'Solitude',
#  'damaging',
#  'odds',
#  'pneumonia',
#  'appendicitis',
#  'whiskey',
#  'generous',
#  'supply',
#  'unbeknownst',
#  'old-timers',
#  'patronizing',
#  'ignorance',
#  'respond',
#  'crisply',
#  'slang',
#  'claustrophobia',
#  'externalized',
#  'hallucinations',
#  'violence-murder',
#  'dishes.',
#  'nonplussed',
#  'committed',
#  'Undoubtedly',
#  'self-righteously',
#  'individual',
#  'rigors',
#  'loneliness-',
#  'spur-ofthe-moment',
#  'edgy',
#  'aerial',
#  'Finally…',
#  'boom.',
#  'Whereas',
#  'puzzles',
#  'fritz.',
#  'arty',
#  'flies.',
#  'multiplied',
#  'responsibility-',
#  'unattached',
#  'Unless',
#  'feelings.',
#  'shopworn',
#  'planted',
#  'five-yearold',
#  'buttoning',
#  'advance',
#  'splintery',
#  'brick',
#  'rancorous',
#  'earnest-the',
#  'prelim',
#  'Fights',
#  'woman-her',
#  'Elaine-would',
#  'awakened',
#  'bluster',
#  'normal-excuse',
#  'abnormal',
#  'Sweeping',
#  'perfunctory',
#  'sneakered',
#  'suppertime',
#  'matter-of-fact',
#  'Fuel',
#  'vulgar.',
#  'bugmotor',
#  'sbit',
#  'wait.',
#  'Hokay.',
#  'brighter',
#  'closemouthed',
#  'spending',
#  'age-and',
#  'preschool-but',
#  'neighborhood',
#  'apartments',
#  'attending',
#  'CU',
#  'infants',
#  'jolted',
#  'floundering',
#  'varied',
#  'varnish',
#  'motives',
#  'puppets',
#  'vaguest',
#  'notions',
#  'disabled',
#  'coaching',
#  'Arguments',
#  'SPEEDOGLIDE',
#  'daddy…',
#  'Sometimes-',
#  'deluge',
#  'her-',
#  'five.',
#  'answers',
#  'spectrum',
#  'rosy',
#  'Andy',
#  'lightcolored',
#  'baby-fineness',
#  'solemn',
#  'survive',
#  'Divine',
#  'Placement',
#  'feared',
#  'bystander',
#  'Oreos',
#  'pottery',
#  'bluejeans',
#  'over-sized',
#  'threatened',
#  'cloudburst',
#  'fragrant',
#  'musty-smelling',
#  'beefy',
#  'popcorn',
#  'chinos',
#  'blue-white',
#  'barbecue',
#  'fail-safe',
#  'sensor',
#  'measures',
#  'falls',
#  'Boiler',
#  'bulk',
#  'radiated',
#  'stuporous',
#  'your-',
#  'eclipsed',
#  'subjectively',
#  'ransacked',
#  'Closet',
#  'manuscript',
#  'threeact',
#  'developing',
#  'novelette',
#  'under-graduate',
#  'corrections',
#  'out-of-tune',
#  'completing',
#  'eraser',
#  'truth…',
#  'Spike',
#  'Jones',
#  'HUGE',
#  'arrow-',
#  'remorse',
#  'agonizing',
#  'past-is',
#  'quo',
#  '-saying',
#  'families',
#  'practical',
#  'wedged',
#  'thinking-',
#  'humid',
#  'humidity',
#  'slimy',
#  'lag',
#  'revulsion',
#  'blacker',
#  'despair-would',
#  'decisive',
#  'cylindrical',
#  'copper-jacketed',
#  'ducts',
#  'cobweb-festooned',
#  'adjoining',
#  'Pressure',
#  'Pounds',
#  'overalls.',
#  'tinkering',
#  'cuttin',
#  'rakin',
#  'mum',
#  'bless',
#  'crazyman',
#  'Yap-yap-yap',
#  'livelong',
#  'bites',
#  'pullin',
#  'Yellow',
#  'catches',
#  'whoops',
#  'frigid',
#  'thermostats',
#  'upstairs-',
#  'vehemently',
#  'bounce',
#  'soliloquized',
#  'ninety-one',
#  'peckerwood',
#  'spends',
#  '1982',
#  'charitable',
#  'eighty.',
#  'shutdown',
#  'required',
#  'FBI',
#  'mail',
#  'buggin',
#  'phones…',
#  'amazin',
#  'arch.',
#  'seventyfive-watt',
#  'sickish',
#  'pulleys',
#  'grease-clogged',
#  'boxed',
#  'Records',
#  'Invoices',
#  'ReceiptsSAV',
#  'inspector',
#  'dinners',
#  'repairman',
#  'core.',
#  'cinched',
#  'rags',
#  'looseleaf',
#  'binder',
#  'leaks-never',
#  'been-but',
#  'durin',
#  'remarkably',
#  'astute',
#  'analysis.',
#  'admiringly',
#  'fairy-boys',
#  'Lots',
#  'riots',
#  'hommasexshuls',
#  'frustrated',
#  'Comin',
#  'unstrap',
#  'core',
#  'fret',
#  'Beastly',
#  'Cobwebby',
#  'Gives',
#  'egg-suck',
#  'startin',
#  'Strangler',
#  "he'd",
#  'Cute',
#  'cut-buttons',
#  'manages',
#  'honky-tonky',
#  'closed-a',
#  'Post',
#  'bituary',
#  'pissant',
#  'considerin',
#  'reporter',
#  'excuse',
#  'scandals.',
#  'Hotels',
#  'twenty-two',
#  'messes',
#  'old-my',
#  '-and',
#  'dyed',
#  'stoplight',
#  'saggin',
#  'wearin',
#  'brassy-ear',
#  'varycoarse',
#  'roadmaps',
#  'jools',
#  'hangin',
#  'bulgin',
#  "'like",
#  'funnypages',
#  'drill',
#  'slings',
#  'outlaw',
#  'Olympia',
#  'primed',
#  'walkin',
#  'staggerin',
#  'coot',
#  'pinchin',
#  'waitresses',
#  'bets',
#  'last.',
#  "'wife",
#  "'indisposed'-",
#  'there-and',
#  'asks',
#  'diplomatic-like',
#  'notify',
#  'No-no-no',
#  'tenthirty',
#  'alive.',
#  'County',
#  'sleepin',
#  'pills',
#  'big-shot',
#  'underwear',
#  'sucker',
#  'bigshot',
#  'Wife',
#  'Prominent',
#  'Found',
#  'Bellyful',
#  'Pills',
#  'hide-the-salami',
#  'grandson',
#  'allnight',
#  'burger',
#  'ganged',
#  'Houghton',
#  'county',
#  'verdict',
#  'accidental',
#  'Chrysler',
#  'begrudge',
#  'years.',
#  'Honk',
#  'Peek',
#  'helluva',
#  'faints',
#  "'Her",
#  "'an",
#  'forty-fifty',
#  '1910.',
#  'shrewdly',
#  'bangin',
#  'resorts',
#  'fling',
#  'pretend',
#  'somethin',
#  'Biltmore',
#  "older'n",
#  'snapshot',
#  'shed.',
#  'kiddin',
#  'Seems',
#  'wood-burning',
#  'expense',
#  "wouldn't.",
#  'advice',
#  'reshingled.',
#  'for-free',
#  'drone',
#  'mustysmelling',
#  'berserk',
#  'committing',
#  'atrocity',
#  'knell',
#  'snap-like',
#  'gobbled',
#  'faster-but',
#  'lengthening',
#  'tinged',
#  'Turning',
#  'Skip',
#  'sung',
#  'Nursery',
#  'adding',
#  'loneliness',
#  'blamed',
#  'Andy-mostly',
#  'Scott-but',
#  'understandings',
#  'understand-vague',
#  'selfimage',
#  'them-but',
#  'Aaronson',
#  'poisonous',
#  'word-or',
#  'understandings-floating',
#  'diffuse',
#  'relatively',
#  'thunderheads',
#  'messing',
#  'interpret',
#  'moods',
#  'pissed',
#  'daddyhurt',
#  'put-putting',
#  'about…about…',
#  'things-real',
#  'things-go',
#  'pregnant',
#  'normallv',
#  'playmate.',
#  'Loo',
#  'Sin',
#  'Nation',
#  'SUICIDE',
#  'woozy',
#  'swimmy',
#  'cleared-',
#  'fact-but',
#  'beckoning…',
#  'Alice',
#  'Wonderland',
#  'PLAY.',
#  'thestairs',
#  'right…',
#  'under…',
#  'marvel',
#  'back-yard',
#  'stomping',
#  'landlord',
#  'his…',
#  'furrowed',
#  'eyes-that',
#  'necessary-but',
#  'squinched',
#  'quirking',
#  'deepening',
#  'Thinking…',
#  'ok',
#  'watson',
#  'sidewinder',
#  'nesting',
#  'Dannee…',
#  'jar-of',
#  'laxly',
#  'fork',
#  'painless',
#  'gale',
#  'rearing',
#  'Huge',
#  'Whiteness',
#  'shingled',
#  'witchlight',
#  'Poison',
#  'Poison.',
#  'SWIMMING',
#  'LIVE',
#  'WIRES',
#  'PROPERTY',
#  'CONDEMNED',
#  'HIGH',
#  'VOLTAGE',
#  'THIRD',
#  'RAIL',
#  'DEATH',
#  'VIOLATORS',
#  'BE',
#  'SHOT',
#  'SIGHT',
#  'completely-he',
#  'hollows',
#  'spores',
#  'spattered',
#  'triphammering',
#  'Footfalls',
#  'bubble',
#  'frosted',
#  'drapes',
#  'Smashing',
#  'Approaching',
#  'madman',
#  'familiarity',
#  'Came',
#  'Splintering',
#  'Grieg',
#  'Handel',
#  'Beatles',
#  'Art',
#  'Garfunkel',
#  'Liszt',
#  'Broken',
#  'pie',
#  'REDRUM-',
#  'Limp',
#  'nail-',
#  'Fading',
#  'riot',
#  'plasterdust',
#  'advancing',
#  'sweet-sour',
#  'wicked',
#  'itchy',
#  'cowering',
#  'contrapuntal',
#  'voided',
#  'extremity',
#  'inexplicable',
#  'doc…',
#  'chattering',
#  'farting',
#  'jiving',
#  'groceries',
#  'sweat.',
#  'waiting.',
#  'stroneest',
#  'hobby',
#  'corners.',
#  'groceries-just',
#  'groceries-crackled',
#  'indecipherable',
#  'Rexall',
#  'Mesa',
#  'honors',
#  'roof…',
#  'beetles',
#  'bar.',
#  'stuff.',
#  'Check.',
#  'finances',
#  'argued',
#  'child-especially',
#  'spells-they',
#  'forked',
#  'thirty-dollar',
#  'installation',
#  'fee',
#  'deposit',
#  'mute',
#  'maps.',
#  'glovebox',
#  'Nebraska',
#  'keymaking',
#  'studiously',
#  'stony',
#  'grimness',
#  'obligatory',
#  'thank-you',
#  'schools',
#  'friends-although',
#  'wagon-some',
#  'laughs',
#  'deft',
#  'dedication',
#  'two-week',
#  'savings',
#  'penny',
#  'rounds',
#  'payment',
#  'farmhouse',
#  'renovate',
#  'headmasters',
#  'engravings',
#  '1879',
#  '1895',
#  'Vanderbilt',
#  'enabled',
#  'fucked',
#  'Terribly',
#  'convey',
#  'resignation',
#  'Under',
#  'darkest',
#  'frayed',
#  'leash',
#  'sampling',
#  'waters',
#  'oblivion',
#  'vote',
#  'eighty-five',
#  'relative',
#  'Faintly',
#  'boops',
#  'beeps',
#  'sniffing',
#  'eastward',
#  'Longley',
#  'baron',
#  'directorships',
#  'Preparatory',
#  'alumni',
#  'affairs',
#  'coach',
#  'uncoincidental',
#  'drunkest',
#  'skidding',
#  'frequently',
#  'reform',
#  'seeping',
#  'self-loathing',
#  'martinis-martians',
#  'sanely',
#  'bender',
#  'weeknight',
#  'Poets',
#  'Red-Eyed',
#  'Longfellow',
#  'fenders',
#  'Cautious',
#  'colleagues',
#  'blooming',
#  'qualified',
#  'incubating',
#  'erratic',
#  'will…',
#  'fancily',
#  'starred',
#  'jockeying',
#  'stanchion',
#  'zigzagging',
#  'loops',
#  'Tacky-boy.',
#  'four-way',
#  'flashers',
#  'searched',
#  'beached',
#  'Jaguar',
#  'providence',
#  'passersby',
#  'hiked',
#  'bachelor',
#  'surveyed',
#  'jacking',
#  'lug',
#  'Providentially',
#  'Pay',
#  'martian.',
#  'phonebootb',
#  'disco',
#  'chanted',
#  'wanta',
#  'nurses',
#  'pediatrics',
#  'snot',
#  'accident-',
#  'hunted',
#  'weeds',
#  'Spanish',
#  'Llama',
#  'thinking.',
#  'about…',
#  'lacy',
#  'suds',
#  'disillusioned',
#  'with-',
#  'pick-me-up',
#  'perspective-',
#  'low-grade',
#  'Bone',
#  'Lon',
#  'Chaney',
#  'Phantom',
#  'Opera.',
#  'two-handed',
#  'whist',
#  'believing',
#  'Coca-Cola',
#  'six-pack',
#  "Shockley's-she",
#  'anyone-and',
#  'lucidly',
#  'themes',
#  'Weeks',
#  'retirement',
#  "doesn't-",
#  'dourly',
#  'Genuine',
#  'beyond.',
#  'bitched',
#  'hasty',
#  'something-',
#  'restless-',
#  'Glad',
#  'space-filler',
#  'abstracted',
#  'Um-hm.',
#  'glove',
#  'rueful',
#  'melancholy',
#  'pleasing',
#  'Lovin',
#  'rollin',
#  'log',
#  'Billie',
#  'Holiday',
#  'prosaic',
#  'Peggy',
#  'Lee',
#  'torchy',
#  'Wurlitzer',
#  'apartment…',
#  'semester',
#  'jobs',
#  'rusty',
#  'forgiveness',
#  'eye-he',
#  'half-humorous',
#  'halfscowling',
#  'that-telling',
#  'darken',
#  'cramp',
#  'fool',
#  'while-to',
#  'perspective',
#  'quirt',
#  'Shadow',
#  'spying',
#  'awkward-as',
#  'guess…',
#  'proposing',
#  'profs-quizzes',
#  'exams',
#  'syllabi',
#  'lists',
#  'tvping',
#  'published…',
#  'irreverent',
#  'glee',
#  'skyrocketed',
#  'unsuccessful',
#  'Bright',
#  'upwardly',
#  'mobile',
#  'marrieds',
#  'formula',
#  'rash',
#  'privates',
#  'overtly',
#  'inadequate',
#  'housewife',
#  'sunwashed',
#  'four-room',
#  'second-story',
#  'portable',
#  'stereo',
#  'erased',
#  'assignments',
#  'Sun',
#  'someday…',
#  'sociology',
#  'Pepys',
#  'diaries',
#  'Olson',
#  'poetry',
#  'cupping',
#  'braceleting',
#  'competition',
#  'sessions',
#  'therapy',
#  'grad',
#  'stories-four',
#  'subscription',
#  'Concerning',
#  'Holes',
#  'publication',
#  'goggle',
#  'creamed',
#  'puree',
#  'weighted',
#  'ceremonial',
#  'toast',
#  'Veni',
#  'vidi',
#  'vici.',
#  'cheers',
#  'ambulatory',
#  'owlishly',
#  'moccasins',
#  'drive.',
#  'Tonight',
#  'soothe',
#  'else-',
#  'both-and',
#  'prophecy',
#  'fools',
#  'Congratulations',
#  'Danny-he',
#  'concussion.',
#  'bruise.',
#  'repentant',
#  'departed',
#  'sickened',
#  "shouldn't…",
#  'restlessly',
#  'linear',
#  'encroaching',
#  'worsening',
#  'ebb',
#  'nook',
#  'sandpile',
#  'grizzled',
#  'jittering',
#  'pondered',
#  'pondering',
#  'good-he',
#  'broke-and',
#  'accident-if',
#  'accident-she',
#  'lopsided',
#  'dumbly',
#  'slowdown',
#  'beers',
#  'grading',
#  'dreaded',
#  'recooked',
#  'and/or',
#  'redistributed',
#  'unsuitable',
#  'spirited',
#  'attic…',
#  'Mine',
#  'adulthood',
#  'handwriting',
#  'Accidentally',
#  'Already',
#  'sympathetic',
#  'messy',
#  'visitation',
#  'feet-and',
#  'unrestful',
#  ...]

# %%
import re

def sum_monetary_amounts(tokens):
    # Регулярний вираз для виявлення грошових сум
    pattern = r'\$\d+\.\d{0,1}'

    # Знаходимо всі входження грошових сум у тексті
    matches = re.findall(pattern, ' '.join(tokens))

    # Конвертуємо входження у числа з плаваючою точкою
    amounts = [float(match[1:]) for match in matches]

    total = sum(amounts)
    return total


with open('Shining.txt', 'r') as file:
    text = file.read()
    tokens = nltk.sent_tokenize(text)

total_amount = sum_monetary_amounts(tokens)

print("Загальна сума грошових виплат:", total_amount)
# Out:
# Загальна сума грошових виплат: 123.2

# %%
import json
import re

initial_data = {
    "HTTPHost": "localhost",
    "HTTPPort": 8545,
    "Config": {
        "Enabled": True,
        "Server": "wakuv2.prod",
        "Nodes": [
            "8.210.222.231",
            "168.166.125.145",
            "192.168.0.1",
            "8.210.222.234",
            "8.210.222.588"
        ]
    }
}


with open('initial_data.json', 'w') as file:
    json.dump(initial_data, file, indent=4)

with open('initial_data.json', 'r') as file:
    data = json.load(file)

data['Config']['Nodes'] = [node for node in data['Config']['Nodes'] if not re.match(r'^8\.', node)]

server_name, server_type = re.match(r'(\w+)\.(\w+)', data['Config']['Server']).groups()
data['Config']['Server'] = {"name": server_name, "type": server_type}

with open('edited_data.json', 'w') as file:
    json.dump(data, file, indent=4)

# %%
import json

# Зчитування відредагованого JSON файлу
with open('edited_data.json', 'r') as file:
    edited_data = json.load(file)

# Виведення вмісту відредагованого JSON файлу
print(json.dumps(edited_data, indent=4))
# Out:
# {
#     "HTTPHost": "localhost",
#     "HTTPPort": 8545,
#     "Config": {
#         "Enabled": true,
#         "Server": {
#             "name": "wakuv2",
#             "type": "prod"
#         },
#         "Nodes": [
#             "168.166.125.145",
#             "192.168.0.1"
#         ]
#     }
# }
