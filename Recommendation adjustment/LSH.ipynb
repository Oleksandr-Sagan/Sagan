# %%
import numpy as np
import pandas as pd
from LocalitySensitiveHashing import *

# %%
documents = np.load('documents.npy')

# %%
documents = np.load('documents.npy')

df = pd.DataFrame(documents)
df.to_csv('documents.csv', index=False)

lsh = LocalitySensitiveHashing(
    datafile='documents.csv',
    dim=len(documents[0]),
    r=15,
    b=30,
    expected_num_of_clusters=3,
)

lsh.initialize_hash_store()

lsh.hash_all_data()

similarity_groups = lsh.lsh_basic_for_neighborhood_clusters()
# Out:
# Similarity neighborhoods calculated by the basic LSH algo:
#
#
# Similarity groups calculated by the basic LSH algo:
#
#
# Total number of similarity groups found by the basic LSH algo: 0
